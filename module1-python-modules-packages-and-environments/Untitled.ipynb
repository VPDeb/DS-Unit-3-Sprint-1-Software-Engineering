# %%
 pip install -i https://test.pypi.org/simple/ trees-character-bsmrvl
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from treescharacter import tree

# %%
var = tree.Ecosystem()

# %%
var.grow()

# %%
var.show()
# Out:
# ````````````````````````````````````````````````````````````````````````````````````````````````````
# ````````````````````````````````````````````````````````````````````````````````````````````````````
# ``````````````````````````````````````````````````$`$$``````````````````````````````````````````````
# ```````````````````````````````````````$$`````````$$$```````````````````````````````````````````````
# `````````````````````````````````````$$$$`````````$$``````````````$$````````````````````````````````
# ```````````````````````````````````$```$$````````$$````````````$`$$`````````````````````````````````
# ```````````````````````````````````$````$````````$$````````````$$$````$`````````````````````````````
# ````````````````````````````````````$$$``$$`````$$``````````````$`````$`````````````````````````````
# ````````````````````````````````````$````$$$````$$`````````````$```$`$````$```````````````$`````````
# ...

# %%
var = tree.Ecosystem('?')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-0261c4492468> in <module>
# ----> 1 var = tree.Ecosystem('?')
#
# ~/.local/share/virtualenvs/DS-Unit-3-Sprint-1-Software-Engineering-BU1N3AG5/lib/python3.8/site-packages/treescharacter/tree.py in __init__(self, size)
#      28     def __init__(self, size=[50,40]):
#      29         self.w = size[0]*2
# ---> 30         self.h = size[1]
#      31         self.plot = 'Nothing has grown!'
#      32
#
# IndexError: string index out of range
